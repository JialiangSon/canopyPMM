# %%
import numpy as np
import matplotlib.pylab as plt
plt.rc('font',family='Times New Roman')
#####################################
plt.tick_params(top=True,right=True)
plt.rcParams['ytick.direction']='in'
plt.rcParams['xtick.direction']='in'
plt.tick_params(labelsize=16)
axes=plt.subplot()
# axes.minorticks_on()
# plt.tick_params(which='major',width=2)
plt.tick_params(which='major',length=6)
# plt.tick_params(which='minor',width=2)
# plt.tick_params(which='minor',length=3)
#####################################

plt.legend(fontsize=16)
plt.xlabel(r'$\theta$',fontsize=16)
plt.ylabel('C$_{p}$',fontsize=16)

my = np.loadtxt('Cp_angle/Results.csv')
C2023 = np.loadtxt('Cp_angle/Chen(2023).csv')
N1993 = np.loadtxt('Cp_angle/Norberg(1993).csv')

plt.scatter(my[:,0],my[:,1],c='k',marker='+',label='Presne work')
plt.scatter(N1993[:,0],N1993[:,1],c='r',label='Norberg(1998)_EXP')
plt.scatter(C2023[:,0],C2023[:,1],marker='o',c='None',edgecolors='b',label='Chen(2023)_DNS')

plt.xlim([0,180])
# plt.ylim([-0.4,1.2])


#####################################
plt.tick_params(top=True,right=True)
plt.rcParams['ytick.direction']='in'
plt.rcParams['xtick.direction']='in'
plt.tick_params(labelsize=14)
axes=plt.subplot()
# axes.minorticks_on()
# plt.tick_params(which='major',width=2)
plt.tick_params(which='major',length=6)
# plt.tick_params(which='minor',width=2)
# plt.tick_params(which='minor',length=3)
#####################################
plt.legend(fontsize=14)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
